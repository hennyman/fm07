# %%
int("12")
# Out:
# 12

# %%
int("ab")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-00e9cb07ad41> in <module>
# ----> 1 int("ab")
#
# ValueError: invalid literal for int() with base 10: 'ab'

# %%
x = "ab"

# %%
try:
    a = int(x)
except Exception as e:
    a = x

# %%
a
# Out:
# 'ab'

# %%
a = "Henrik Nyman".split(" ")

# %%
a
# Out:
# ['Henrik', 'Nyman']

# %%
d={}

# %%
d[744] = "Jaro"

# %%
d
# Out:
# {744: 'Jaro'}

# %%
d[744]
# Out:
# 'Jaro'

# %%
744 in d
# Out:
# True

# %%
with open("./shortlists/interested.slf", 'rb') as f:
            hexdata_interested = f.read().hex()

# %%
a=["hej", "jepp"]

# %%
print(a)
# Out:
# ['hej', 'jepp']

# %%
b = "vi" + a
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-2a3434c2a245> in <module>
# ----> 1 b = "vi" + a
#
# TypeError: can only concatenate str (not "list") to str

# %%
str(a)
# Out:
# "['hej', 'jepp']"

# %%
import json

# %%
with open('./player_search_jsons/young.json') as json_file:  
    data = json.load(json_file)

# %%
data
# Out:
# {'filter': {'age': {'max': 18},
#   'positions': ['all_outfield'],
#   'interested': True},
#  'sort': 'total',
#  'max_return': 20}

# %%
data.filter
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-f48afd0a5097> in <module>
# ----> 1 data.filter
#
# AttributeError: 'dict' object has no attribute 'filter'

# %%
data.keys()
# Out:
# dict_keys(['filter', 'sort', 'max_return'])

# %%
data["filter"]
# Out:
# {'age': {'max': 18}, 'positions': ['all_outfield'], 'interested': True}

# %%
filters_keys = data["filter"].keys()

# %%
"age" in filters_keys
# Out:
# True

# %%
    try:
        with open("./shortlists/interested.slf", 'rb') as f:
            data = f.read().hex()
    except Exception as e:
        print(e)

# %%
data
# Out:
# '...'

# %%
a='what the world needs now'

# %%
'what ' in a
# Out:
# True

# %%
'51687300' in data
# Out:
# True

# %%
'1400000' in data
# Out:
# True

# %%
len(data)
# Out:
# 111454

# %%
len(data)/8
# Out:
# 13931.75

# %%
a = [1,2,3,4,5,5,5,6]

# %%
b = [5,5,6,7]

# %%
list(set(a) & set(b))
# Out:
# [5, 6]

# %%
len(list(set(a) & set(b)))
# Out:
# 2

# %%
5/2
# Out:
# 2.5

# %%
str('Hello')
# Out:
# 'Hello'

# %%
starting = []
second = []
goalkeepers = [2,3,4]
full_backs = [4,5,6]
matrix = [goalkeepers, full_backs]

# %%
for i in range(2):
    if len(matrix[i]) > 0:
        starting.append(matrix[i][0])
        matrix[i].remove(matrix[i][0])
    if len(matrix[i]) > 0:
        second.append(matrix[i][0])
        matrix[i].remove(matrix[i][0])

# %%
starting
# Out:
# [2, 4]

# %%
second
# Out:
# [3, 5]

# %%
12/2
# Out:
# 6.0

# %%
12%11
# Out:
# 1

# %%
import math

# %%
math.floor(11/11)
# Out:
# 1

# %%
starting.remove(4)
